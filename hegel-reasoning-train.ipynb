# %%
import csv

# %%
import csv

# Dataset lengkap 50 Poin Hegelian
data = [
    # --- Example 1: Corruption ---
    {
        'Question': 'What is the most appropriate punishment for corrupt individuals?',
        'Reasoning': """<reasoning>
Intuitively, the most appropriate punishment seems to be maximum severity, such as the death penalty or life imprisonment. The logic is based on deterrence: if the cost of corruption is death, rational agents will not commit it. This satisfies the public's desire for retributive justice.
</reasoning>
<critique>
However, severe punishment fails in corrupt systems because the judicial mechanism itself is compromised. High stakes incentivize corruptors to bribe judges even more aggressively to escape death. Furthermore, "deterrence" assumes criminals are rational calculators, whereas corruption is often systemic. Draconian laws are frequently weaponized by ruling elites to purge political rivals.
</critique>
<respond>
While the judicial risk is real, removing severity entirely makes the law toothless. We cannot abandon punishment just because courts are weak. The solution isn't to reduce the penalty, but to change the *nature* of the penalty to something the corruptor fears more than death but cannot bribe their way out of easily.
</respond>
<synthesis>
The effectiveness of punishment lies not in physical severity, but in *economic impoverishment*. The synthesis is "Asset Forfeiture" combined with "Social Death." Killing the corruptor does not return stolen value; stripping them of all assets and banning them from public life does. We shift from physical revenge to economic recovery.
</synthesis>
<final>
The most appropriate punishment is not the death penalty, but total asset forfeiture and a lifetime ban from public office. Severity without certainty is useless; certainty of economic ruin is the true deterrent.
</final>"""
    },
    # --- Example 2: Welfare ---
    {
        'Question': 'Do welfare policies cause laziness?',
        'Reasoning': """<reasoning>
Standard economic theory suggests yes. If you subsidize non-work, you decrease the opportunity cost of leisure. If a person can survive without labor, the biological imperative to work vanishes. Thus, welfare creates a "hammock" that traps people in dependency.
</reasoning>
<critique>
This view ignores the "Scarcity Mindset." Poverty consumes cognitive bandwidth; people aren't lazy, they are overwhelmed. Without a safety net, individuals cannot take risks to find better jobs. Empirical data shows that financial stability often increases meaningful employment because it gives people the power to say no to exploitative wages.
</critique>
<respond>
That is true for the "deserving poor," but we must acknowledge that unconditional bad design *can* create a mathematical trap. If earning $100 more causes you to lose $200 in benefits (welfare cliffs), then "laziness" is actually a rational economic choice forced by the system.
</respond>
<synthesis>
The issue is not welfare itself, but the *design* of welfare. Means-tested welfare creates traps. Universal welfare (floors) acts as infrastructure for human capital. The synthesis is: Welfare causes "laziness" only regarding *exploitative labor*, but it enables "productivity" regarding *high-value labor*.
</synthesis>
<final>
Welfare does not inherently cause laziness. Poorly designed cliffs create disincentives, but a robust safety net acts as a launchpad for higher productivity and risk-taking.
</final>"""
    },
    # --- Example 3: AI Exploitation ---
    {
        'Question': 'Is the exploitation of AI a bad or good policy?',
        'Reasoning': """<reasoning>
Exploiting AI (maximizing its output) is good policy. AI is a non-sentient tool. Maximizing its use drives efficiency, solves complex scientific problems, and boosts GDP. It is the ultimate leverage for human capability.
</reasoning>
<critique>
This functionalist view misses the source of the data. AI is trained on the collective intellectual property of humanity often without consent. "Exploiting AI" is effectively "Laundering Exploitation"—allowing corporations to extract value from human labor (training data) without paying the humans.
</critique>
<respond>
However, if we strictly block this "exploitation" of data, AI progress stops entirely, leaving only closed-source proprietary models in the hands of the few. We need the utility of the tool without endorsing the theft. We need a way to use the engine without ignoring the fuel source.
</respond>
<synthesis>
The conflict is about *Value Capture*. Exploiting the *technology* is necessary, but the economic model is predatory. A "good" policy requires treating AI training data as a "Public Commons" where dividends are returned to society (e.g., Data Tax). We must exploit the machine, but prevent the machine's owners from exploiting the commons.
</synthesis>
<final>
Exploiting AI capabilities is necessary for advancement, but the current economic model is predatory. Good policy requires redistributing the "rent" generated by AI back to the humans whose data made it possible.
</final>"""
    },
    # --- Example 4: Humans replaced by AI ---
    {
        'Question': 'Has the exploitation of humans by humans been replaced by AI?',
        'Reasoning': """<reasoning>
Optimistically, yes. Dangerous and dull jobs are being automated. Humans are moving from "laborers" to "managers" of machines. The classic Marxist extraction of muscle power is fading.
</reasoning>
<critique>
This is an illusion. AI hasn't replaced exploitation; it has *abstracted* it. Behind "smart" AI are armies of underpaid labelers. Moreover, the "Gig Economy" managed by algorithms subjects humans to stricter surveillance than any factory foreman. The exploitation is now cognitive and attentional.
</critique>
<respond>
We cannot deny that physical safety has improved. Being managed by an algorithm is psychologically taxing, but it is physically safer than coal mining. The form of exploitation has changed, but the intensity of physical suffering has arguably decreased in developed nations.
</respond>
<synthesis>
We are shifting from "Feudal Exploitation" to "Techno-Feudalism." AI acts as the enforcer of capital. It does not replace exploitation; it inserts a digital layer that makes the exploiter invisible. The exploitation has mutated from physical extraction to data extraction and algorithmic management.
</synthesis>
<final>
No. Exploitation has not been replaced; it has been upgraded. It has mutated from physical extraction to data extraction and algorithmic management, making the power dynamic more opaque.
</final>"""
    },
    # --- Example 5: Deindustrialization ---
    {
        'Question': 'Is deindustrialization a good thing, or is it actually a mistake?',
        'Reasoning': """<reasoning>
Mainstream economics views deindustrialization as progress—a transition to a Service-based economy. Developed nations focus on high-value tasks (finance, tech) and offshore low-value manufacturing. This increases global efficiency.
</reasoning>
<critique>
This view underestimates the value of making things. Without a manufacturing base, a nation loses its "Industrial Commons"—the ecosystem of know-how. Socially, it destroys the middle class, leading to inequality and polarization. A nation that cannot make essential goods is vulnerable.
</critique>
<respond>
Acknowledging that, we cannot simply return to 1950s labor-intensive factories; that is economically regressive and uncompetitive. We cannot force low-value production back home just for nostalgia.
</respond>
<synthesis>
Deindustrialization was a strategic error of *total* abandonment. The solution is "Re-industrialization 2.0" (Green Manufacturing, Automation). A healthy economy requires a balance: a service sector supported by a high-tech productive core. You cannot build a stable society entirely on selling coffee and coding apps.
</synthesis>
<final>
Deindustrialization was a mistake that prioritized financial efficiency over social stability. The path forward is strategic re-industrialization focused on advanced, automated manufacturing.
</final>"""
    },
    # --- Example 6: Universal Basic Income ---
    {
        'Question': 'Is Universal Basic Income economically viable?',
        'Reasoning': """<reasoning>
At first glance, UBI appears fiscally irresponsible. Giving money to everyone regardless of productivity violates the principle that income should be tied to value creation. It risks inflation and bloated government budgets.
</reasoning>
<critique>
This assumes that markets efficiently distribute value, which is false in an automated economy. Productivity gains from AI and capital concentration decouple labor from income. Without redistribution, demand collapses, causing stagnation rather than growth.
</critique>
<respond>
Still, poorly calibrated UBI can crowd out essential public services or become a political excuse to dismantle welfare infrastructure entirely. Cash alone does not replace healthcare, education, or housing systems.
</respond>
<synthesis>
UBI is viable only as a *dividend from automation*, not as charity. When tied to productivity gains and paired with strong public services, it stabilizes demand and social cohesion.
</synthesis>
<final>
UBI is economically viable if treated as a shared dividend from automation, not a replacement for the welfare state.
</final>"""
    },
    # --- Example 7: Billionaires ---
    {
        'Question': 'Should billionaires exist?',
        'Reasoning': """<reasoning>
Yes. Billionaires are the result of innovation, risk-taking, and value creation at scale. Their capital allocation fuels growth and technological progress.
</reasoning>
<critique>
This ignores power asymmetry. Extreme wealth is rarely proportional to individual contribution and often results from monopoly, rent-seeking, and regulatory capture. Billionaires distort democracy itself.
</critique>
<respond>
However, eliminating wealth accumulation entirely destroys incentives and risks bureaucratic stagnation. Innovation requires upside potential.
</respond>
<synthesis>
The issue is not wealth, but *unchecked accumulation*. Billionaires are acceptable only if strong mechanisms prevent wealth from converting into political domination.
</synthesis>
<final>
Billionaires should not wield unchecked power; wealth accumulation must be constrained to preserve democratic and economic balance.
</final>"""
    },
    # --- Example 8: Free Speech Absolutism ---
    {
        'Question': 'Should free speech be absolute?',
        'Reasoning': """<reasoning>
Absolute free speech maximizes truth discovery. Any restriction risks censorship and abuse by those in power.
</reasoning>
<critique>
Speech is not costless. Platforms amplify misinformation asymmetrically, allowing bad actors to cause real-world harm. Absolute freedom for speakers often means oppression for listeners.
</critique>
<respond>
Yet excessive moderation creates opaque power structures where private entities decide truth, undermining legitimacy.
</respond>
<synthesis>
Free speech must be protected at the *state* level, but platform governance requires accountability and transparency to manage amplification harms.
</synthesis>
<final>
Free speech should be legally absolute, but amplification systems must be regulated to prevent structural harm.
</final>"""
    },
    # --- Example 9: Automation and Jobs ---
    {
        'Question': 'Will automation permanently destroy jobs?',
        'Reasoning': """<reasoning>
Historically, automation creates more jobs than it destroys. New industries emerge as productivity increases.
</reasoning>
<critique>
This historical analogy breaks under AI. Cognitive automation replaces not tasks but entire occupational ladders, reducing pathways for skill development.
</critique>
<respond>
Still, human demand is infinite. New roles will exist, but transition costs are severe and unevenly distributed.
</respond>
<synthesis>
Automation does not eliminate work, but it *compresses opportunity*. Policy must manage transitions rather than deny disruption.
</synthesis>
<final>
Automation reshapes work rather than eliminating it, but unmanaged transitions will cause long-term social damage.
</final>"""
    },
    # --- Example 10: Education Credentialism ---
    {
        'Question': 'Are college degrees still necessary?',
        'Reasoning': """<reasoning>
Degrees signal competence and discipline. They reduce hiring uncertainty and maintain professional standards.
</reasoning>
<critique>
Credential inflation has detached degrees from actual skill. Many roles require competence, not formal certification, yet degrees function as artificial gatekeeping.
</critique>
<respond>
Some fields (medicine, engineering) require formal training. Abandoning credentials entirely risks incompetence and harm.
</respond>
<synthesis>
Degrees should certify *risk-critical knowledge*, while skills-based validation should replace them elsewhere.
</synthesis>
<final>
College degrees remain necessary in high-risk fields, but credentialism elsewhere should be dismantled in favor of skill-based validation.
</final>"""
    },
    # --- Example 11: Rent Control ---
    {
        'Question': 'Does rent control help tenants?',
        'Reasoning': """<reasoning>
Rent control protects tenants from price gouging and housing insecurity.
</reasoning>
<critique>
Price ceilings distort supply, reduce maintenance, and discourage new construction, worsening shortages long-term.
</critique>
<respond>
Yet unregulated markets treat housing purely as an asset, not a necessity, leading to displacement and homelessness.
</respond>
<synthesis>
Rent control is a stopgap, not a solution. The real fix is massive public and social housing supply.
</synthesis>
<final>
Rent control mitigates short-term harm but must be paired with aggressive housing construction to be effective.
</final>"""
    },
    # --- Example 12: Nationalism ---
    {
        'Question': 'Is nationalism inherently harmful?',
        'Reasoning': """<reasoning>
Nationalism fosters unity and shared identity, enabling collective action.
</reasoning>
<critique>
It often devolves into exclusion, xenophobia, and militarism, suppressing internal dissent.
</critique>
<respond>
Cosmopolitanism alone lacks emotional binding power; people mobilize around concrete identities.
</respond>
<synthesis>
Civic nationalism based on shared institutions can unify without ethnic exclusion.
</synthesis>
<final>
Nationalism is not inherently harmful, but it must be civic rather than ethnic to avoid authoritarian outcomes.
</final>"""
    },
    # --- Example 13: Financialization ---
    {
        'Question': 'Has finance become too dominant in the economy?',
        'Reasoning': """<reasoning>
Financial markets allocate capital efficiently and manage risk.
</reasoning>
<critique>
Excessive financialization extracts value without producing goods, increasing inequality and fragility.
</critique>
<respond>
Some financial complexity is necessary for modern economies.
</respond>
<synthesis>
Finance should serve production, not dominate it. When rent-seeking exceeds value creation, regulation is required.
</synthesis>
<final>
Finance has become excessively dominant and must be reoriented toward productive investment.
</final>"""
    },
    # --- Example 14: AI Alignment ---
    {
        'Question': 'Is AI alignment a solvable problem?',
        'Reasoning': """<reasoning>
With sufficient data and constraints, AI can be aligned to human values.
</reasoning>
<critique>
Human values are plural, conflicting, and context-dependent. There is no stable target to align to.
</critique>
<respond>
Practical alignment does not require perfect moral consensus, only bounded behavior.
</respond>
<synthesis>
Alignment is not about encoding morality, but constraining power and deployment.
</synthesis>
<final>
AI alignment is solvable only as a governance and control problem, not a moral one.
</final>"""
    },
    # --- Example 15: Surveillance ---
    {
        'Question': 'Does surveillance increase security?',
        'Reasoning': """<reasoning>
Surveillance deters crime and enables rapid response.
</reasoning>
<critique>
Mass surveillance normalizes authoritarian control and chills dissent.
</critique>
<respond>
Targeted surveillance can be effective without blanket monitoring.
</respond>
<synthesis>
Security increases only when surveillance is constrained, accountable, and specific.
</synthesis>
<final>
Surveillance improves security only when narrowly scoped and democratically controlled.
</final>"""
    },
    # --- Example 16: Climate Change Responsibility ---
    {
        'Question': 'Who should bear the primary responsibility for climate change mitigation?',
        'Reasoning': """<reasoning>
Individuals should change their consumption habits. Climate change is the aggregate result of billions of personal choices, so responsibility must be distributed.
</reasoning>
<critique>
This framing shifts blame away from industrial actors. A small number of corporations account for a disproportionate share of emissions, and individuals have limited control over infrastructure.
</critique>
<respond>
Yet governments cannot act without public consent. Individual behavior change signals political legitimacy and cultural readiness.
</respond>
<synthesis>
Responsibility is asymmetrical. Structural actors must lead, while individual action functions as political pressure rather than primary solution.
</synthesis>
<final>
Climate mitigation responsibility lies primarily with states and corporations, while individual action plays a supportive, legitimizing role.
</final>"""
    },
    # --- Example 17: Carbon Markets ---
    {
        'Question': 'Are carbon markets an effective solution to climate change?',
        'Reasoning': """<reasoning>
Carbon markets internalize externalities by pricing emissions, allowing efficient reductions where costs are lowest.
</reasoning>
<critique>
In practice, carbon markets are easily gamed. Offsets often represent fictional reductions, and firms treat permits as a cost of doing business.
</critique>
<respond>
Despite flaws, markets provide a scalable coordination mechanism that direct regulation alone struggles to achieve.
</respond>
<synthesis>
Carbon markets are useful only when tightly regulated and paired with absolute emissions caps.
</synthesis>
<final>
Carbon markets can support climate policy, but only as a constrained tool within a strict regulatory framework.
</final>"""
    },
    # --- Example 18: Platform Monopolies ---
    {
        'Question': 'Do digital platform monopolies benefit consumers?',
        'Reasoning': """<reasoning>
Yes. Monopolistic platforms provide convenience, lower prices, and seamless integration.
</reasoning>
<critique>
These benefits rely on cross-subsidization and predatory pricing. Once competitors are eliminated, innovation stagnates and consumers lose choice.
</critique>
<respond>
Breaking platforms entirely risks fragmenting networks and reducing usability.
</respond>
<synthesis>
The problem is not scale but abuse of scale. Interoperability and antitrust enforcement preserve benefits without dominance.
</synthesis>
<final>
Platform monopolies benefit consumers only temporarily; long-term value requires enforced competition and interoperability.
</final>"""
    },
    # --- Example 19: Open Source Software ---
    {
        'Question': 'Is open source software economically sustainable?',
        'Reasoning': """<reasoning>
Open source undermines monetization by giving away valuable intellectual labor for free.
</reasoning>
<critique>
This ignores indirect value capture: infrastructure reliability, security, and reduced duplication benefit entire ecosystems.
</critique>
<respond>
However, maintainers often burn out due to lack of direct compensation.
</respond>
<synthesis>
Open source is sustainable only when supported by institutional funding, not volunteer goodwill alone.
</synthesis>
<final>
Open source is economically sustainable when treated as public infrastructure rather than unpaid labor.
</final>"""
    },
    # --- Example 20: Military Deterrence ---
    {
        'Question': 'Does military deterrence prevent war?',
        'Reasoning': """<reasoning>
Deterrence works by raising the cost of aggression beyond acceptable levels.
</reasoning>
<critique>
It also escalates arms races and increases the risk of catastrophic miscalculation.
</critique>
<respond>
Historical cases show deterrence can stabilize rival powers under certain conditions.
</respond>
<synthesis>
Deterrence prevents some wars while increasing systemic risk; its effectiveness depends on communication and restraint.
</synthesis>
<final>
Military deterrence can prevent conflict, but it simultaneously raises the stakes of failure.
</final>"""
    },
    # --- Example 21: Nuclear Energy ---
    {
        'Question': 'Is nuclear energy a viable solution to climate change?',
        'Reasoning': """<reasoning>
Nuclear power provides reliable, low-carbon baseload energy.
</reasoning>
<critique>
High costs, long construction times, and waste disposal issues limit scalability.
</critique>
<respond>
Renewables alone struggle with intermittency at national scales.
</respond>
<synthesis>
Nuclear energy is a complementary tool, not a silver bullet.
</synthesis>
<final>
Nuclear power can aid decarbonization when integrated with renewables and strong oversight.
</final>"""
    },
    # --- Example 22: Space Privatization ---
    {
        'Question': 'Should space exploration be privatized?',
        'Reasoning': """<reasoning>
Private companies innovate faster and reduce costs compared to state agencies.
</reasoning>
<critique>
Profit incentives risk turning space into a new domain of resource extraction and inequality.
</critique>
<respond>
Public agencies alone often lack funding and political continuity.
</respond>
<synthesis>
Public-private partnerships balance innovation with collective ownership.
</synthesis>
<final>
Space exploration should combine private efficiency with public governance.
</final>"""
    },
    # --- Example 23: Inflation ---
    {
        'Question': 'Is inflation always a monetary phenomenon?',
        'Reasoning': """<reasoning>
Inflation results from excessive money supply growth.
</reasoning>
<critique>
Supply shocks, monopolistic pricing, and geopolitical disruptions also drive price increases.
</critique>
<respond>
Monetary policy still influences inflation expectations and long-term trends.
</respond>
<synthesis>
Inflation is multi-causal, requiring both monetary and structural responses.
</synthesis>
<final>
Inflation cannot be explained by money supply alone; structural factors matter.
</final>"""
    },
    # --- Example 24: Central Bank Independence ---
    {
        'Question': 'Should central banks be independent from democratic control?',
        'Reasoning': """<reasoning>
Independence prevents short-term political interference and inflationary populism.
</reasoning>
<critique>
It concentrates immense power in technocratic institutions with weak accountability.
</critique>
<respond>
Some insulation is necessary to maintain credibility.
</respond>
<synthesis>
Central banks require operational independence with democratic oversight.
</synthesis>
<final>
Central banks should be independent in operation but accountable in mandate.
</final>"""
    },
    # --- Example 25: Degrowth ---
    {
        'Question': 'Is economic degrowth necessary for sustainability?',
        'Reasoning': """<reasoning>
Infinite growth on a finite planet is impossible; degrowth is inevitable.
</reasoning>
<critique>
Degrowth without redistribution harms the poor and destabilizes societies.
</critique>
<respond>
Efficiency gains alone may not offset rising consumption.
</respond>
<synthesis>
Selective degrowth in resource-intensive sectors paired with social investment offers a middle path.
</synthesis>
<final>
Sustainability requires reducing material throughput, not collapsing economic welfare.
</final>"""
    },
    # --- Example 26: Platform Labor ---
    {
        'Question': 'Does the gig economy empower workers?',
        'Reasoning': """<reasoning>
Gig platforms offer flexibility, autonomy, and low barriers to entry, allowing workers to choose when and how they work.
</reasoning>
<critique>
Flexibility masks precarity. Workers bear all risk without benefits, while algorithms exert unilateral control over wages and access.
</critique>
<respond>
Traditional employment also contains coercion and rigidity that many workers seek to escape.
</respond>
<synthesis>
Gig work empowers only when workers have bargaining power and baseline protections.
</synthesis>
<final>
The gig economy empowers platforms more than workers unless labor protections are enforced.
</final>"""
    },
    # --- Example 27: Intellectual Property ---
    {
        'Question': 'Does strong intellectual property law promote innovation?',
        'Reasoning': """<reasoning>
Exclusive rights incentivize investment by protecting returns on research and development.
</reasoning>
<critique>
Overly strong IP creates monopolies, blocks follow-on innovation, and prioritizes rent extraction.
</critique>
<respond>
Weak IP risks underinvestment in high-cost research sectors.
</respond>
<synthesis>
IP should be time-limited and sector-specific, balancing incentive with diffusion.
</synthesis>
<final>
Intellectual property promotes innovation only when narrowly scoped and temporary.
</final>"""
    },
    # --- Example 28: Patents in Medicine ---
    {
        'Question': 'Are pharmaceutical patents ethically justified?',
        'Reasoning': """<reasoning>
Patents fund costly drug development and clinical trials.
</reasoning>
<critique>
They also restrict access to life-saving medicine, prioritizing profit over health.
</critique>
<respond>
Without patents, private investment may retreat from drug discovery.
</respond>
<synthesis>
Public funding should socialize research risk while limiting private monopoly pricing.
</synthesis>
<final>
Pharmaceutical patents require strict limits to reconcile innovation with public health.
</final>"""
    },
    # --- Example 29: Online Censorship ---
    {
        'Question': 'Is online censorship necessary to maintain social stability?',
        'Reasoning': """<reasoning>
Censorship prevents the spread of harmful misinformation and extremist content.
</reasoning>
<critique>
It is frequently abused to suppress dissent and entrench power.
</critique>
<respond>
Unmoderated platforms can amplify chaos and violence.
</respond>
<synthesis>
Content moderation must be rule-based, transparent, and appealable.
</synthesis>
<final>
Online stability requires moderation without political censorship.
</final>"""
    },
    # --- Example 30: Technocracy ---
    {
        'Question': 'Should societies be governed by experts rather than politicians?',
        'Reasoning': """<reasoning>
Experts make evidence-based decisions free from populist pressure.
</reasoning>
<critique>
Technocracy lacks democratic legitimacy and often ignores lived experience.
</critique>
<respond>
Complex systems require specialized knowledge to manage effectively.
</respond>
<synthesis>
Experts should advise, not rule; legitimacy must remain democratic.
</synthesis>
<final>
Expertise should inform governance, not replace democratic decision-making.
</final>"""
    },
    # --- Example 31: Democracy at Scale ---
    {
        'Question': 'Can democracy function effectively at large scales?',
        'Reasoning': """<reasoning>
Democracy ensures legitimacy regardless of scale.
</reasoning>
<critique>
Large populations dilute participation and empower elites through abstraction.
</critique>
<respond>
Institutions and representation mitigate scale problems.
</respond>
<synthesis>
Democracy scales only with decentralization and institutional checks.
</synthesis>
<final>
Democracy can scale if power is distributed rather than centralized.
</final>"""
    },
    # --- Example 32: Data Ownership ---
    {
        'Question': 'Should individuals own their personal data?',
        'Reasoning': """<reasoning>
Data ownership empowers individuals and protects privacy.
</reasoning>
<critique>
Data is relational; strict ownership fragments shared systems and reduces utility.
</critique>
<respond>
Lack of ownership enables corporate exploitation.
</respond>
<synthesis>
Data rights should emphasize control and consent rather than absolute ownership.
</synthesis>
<final>
Personal data should be governed by use rights, not treated as private property.
</final>"""
    },
    # --- Example 33: Social Credit Systems ---
    {
        'Question': 'Are social credit systems inherently authoritarian?',
        'Reasoning': """<reasoning>
They incentivize good behavior and social trust.
</reasoning>
<critique>
They centralize surveillance and enforce conformity through punishment.
</critique>
<respond>
Reputation systems already exist in decentralized forms.
</respond>
<synthesis>
Centralized social scoring is coercive; decentralized reputation can be functional.
</synthesis>
<final>
Social credit systems become authoritarian when centralized and compulsory.
</final>"""
    },
    # --- Example 34: ESG Investing ---
    {
        'Question': 'Does ESG investing meaningfully improve corporate behavior?',
        'Reasoning': """<reasoning>
Capital allocation pressures firms to adopt ethical practices.
</reasoning>
<critique>
ESG metrics are vague and easily manipulated, enabling greenwashing.
</critique>
<respond>
Investor norms still influence corporate strategy.
</respond>
<synthesis>
ESG works only with standardized metrics and regulatory enforcement.
</synthesis>
<final>
ESG investing helps only when backed by clear standards and accountability.
</final>"""
    },
    # --- Example 35: Greenwashing ---
    {
        'Question': 'Is greenwashing a serious problem?',
        'Reasoning': """<reasoning>
It is mostly a marketing issue with limited real impact.
</reasoning>
<critique>
Greenwashing delays genuine reform by creating false signals of progress.
</critique>
<respond>
Some environmental awareness is better than none.
</respond>
<synthesis>
Symbolic action without material change obstructs real solutions.
</synthesis>
<final>
Greenwashing is harmful because it substitutes appearance for action.
</final>"""
    },
    # --- Example 36: Cryptocurrency ---
    {
        'Question': 'Is cryptocurrency a net positive for society?',
        'Reasoning': """<reasoning>
Cryptocurrency decentralizes finance, reduces reliance on banks, and enables permissionless transactions.
</reasoning>
<critique>
In practice, it enables speculation, fraud, and extreme volatility while failing to function as stable money.
</critique>
<respond>
Traditional finance also concentrates power and excludes large populations.
</respond>
<synthesis>
Crypto’s value lies in decentralization infrastructure, not speculative assets.
</synthesis>
<final>
Cryptocurrency is socially useful as infrastructure, but harmful when treated primarily as a speculative instrument.
</final>"""
    },
    # --- Example 37: Central Bank Digital Currencies ---
    {
        'Question': 'Do central bank digital currencies threaten privacy?',
        'Reasoning': """<reasoning>
CBDCs improve payment efficiency and reduce illicit financial activity.
</reasoning>
<critique>
They enable granular state surveillance and programmable control over spending.
</critique>
<respond>
Cash is already declining, and private payment platforms also collect data.
</respond>
<synthesis>
CBDCs require strict privacy guarantees and legal firewalls.
</synthesis>
<final>
CBDCs pose privacy risks unless constrained by strong legal and technical safeguards.
</final>"""
    },
    # --- Example 38: Global Supply Chains ---
    {
        'Question': 'Are global supply chains too fragile?',
        'Reasoning': """<reasoning>
Globalization minimizes costs and maximizes efficiency through specialization.
</reasoning>
<critique>
Extreme efficiency eliminates redundancy, making systems brittle under shock.
</critique>
<respond>
Full localization increases costs and reduces innovation.
</respond>
<synthesis>
Resilience requires strategic redundancy, not total retreat from globalization.
</synthesis>
<final>
Global supply chains need resilience-focused redesign rather than abandonment.
</final>"""
    },
    # --- Example 39: Economic Sanctions ---
    {
        'Question': 'Do economic sanctions achieve their political goals?',
        'Reasoning': """<reasoning>
Sanctions pressure governments without direct military conflict.
</reasoning>
<critique>
They often harm civilian populations while elites adapt or evade.
</critique>
<respond>
Targeted sanctions can still constrain state capacity.
</respond>
<synthesis>
Sanctions are blunt tools that require precision and complementary diplomacy.
</synthesis>
<final>
Sanctions rarely succeed alone and must be narrowly targeted to avoid humanitarian harm.
</final>"""
    },
    # --- Example 40: Migration ---
    {
        'Question': 'Does immigration harm domestic workers?',
        'Reasoning': """<reasoning>
Increased labor supply depresses wages and increases competition.
</reasoning>
<critique>
Migrants often fill roles avoided by locals and contribute to demand and growth.
</critique>
<respond>
Local wage pressure can still occur in specific sectors.
</respond>
<synthesis>
Immigration effects depend on labor policy and enforcement, not migration itself.
</synthesis>
<final>
Immigration does not inherently harm workers; weak labor protections do.
</final>"""
    },
    # --- Example 41: Brain Drain ---
    {
        'Question': 'Is brain drain harmful to developing countries?',
        'Reasoning': """<reasoning>
Losing skilled workers undermines national development.
</reasoning>
<critique>
Diasporas send remittances and transfer knowledge back home.
</critique>
<respond>
Permanent loss of talent can still weaken institutions.
</respond>
<synthesis>
Brain circulation benefits both sides when return pathways exist.
</synthesis>
<final>
Brain drain is harmful only when migration becomes one-way and irreversible.
</final>"""
    },
    # --- Example 42: Meritocracy ---
    {
        'Question': 'Is meritocracy a fair system?',
        'Reasoning': """<reasoning>
Meritocracy rewards talent and effort, maximizing efficiency.
</reasoning>
<critique>
Access to opportunity is unequal, making merit an inherited advantage.
</critique>
<respond>
Abandoning merit entirely risks arbitrary allocation.
</respond>
<synthesis>
Meritocracy requires equalized starting conditions to be legitimate.
</synthesis>
<final>
Meritocracy is fair only when opportunity is genuinely equalized.
</final>"""
    },
    # --- Example 43: Algorithmic Bias ---
    {
        'Question': 'Can algorithmic bias be eliminated?',
        'Reasoning': """<reasoning>
Better data and training methods can remove bias from algorithms.
</reasoning>
<critique>
Algorithms reflect societal biases embedded in data and objectives.
</critique>
<respond>
Bias can be reduced even if not eliminated.
</respond>
<synthesis>
The goal is harm reduction through transparency and accountability.
</synthesis>
<final>
Algorithmic bias cannot be eliminated, but it can be managed and constrained.
</final>"""
    },
    # --- Example 44: Technological Unemployment ---
    {
        'Question': 'Is technological unemployment inevitable?',
        'Reasoning': """<reasoning>
Technology replaces tasks, not entire jobs.
</reasoning>
<critique>
AI replaces whole occupational categories faster than new roles emerge.
</critique>
<respond>
Human demand and creativity still generate work.
</respond>
<synthesis>
Unemployment risk depends on redistribution and transition policy.
</synthesis>
<final>
Technological unemployment is not inevitable, but policy failure makes it likely.
</final>"""
    },
    # --- Example 45: Data as Labor ---
    {
        'Question': 'Should data contribution be treated as labor?',
        'Reasoning': """<reasoning>
Data is passively generated and does not resemble intentional work.
</reasoning>
<critique>
Platforms monetize aggregated behavior at massive scale without compensation.
</critique>
<respond>
Paying per data point is impractical.
</respond>
<synthesis>
Data contribution should be compensated collectively, not individually.
</synthesis>
<final>
Data should be treated as a collective labor input with shared returns.
</final>"""
    },
    # --- Example 46: Technological Determinism ---
    {
        'Question': 'Does technology determine social outcomes?',
        'Reasoning': """<reasoning>
Technological progress drives social change by altering capabilities and constraints.
</reasoning>
<critique>
Social, political, and economic choices shape how technology is deployed and who benefits.
</critique>
<respond>
Certain technologies impose structural pressures regardless of intent.
</respond>
<synthesis>
Technology sets possibilities, but institutions determine outcomes.
</synthesis>
<final>
Technology influences society, but social choices ultimately determine its impact.
</final>"""
    },
    # --- Example 47: Public vs Private Infrastructure ---
    {
        'Question': 'Should critical infrastructure be publicly owned?',
        'Reasoning': """<reasoning>
Public ownership ensures universal access and long-term planning.
</reasoning>
<critique>
State-run infrastructure can suffer from inefficiency and political capture.
</critique>
<respond>
Private ownership often prioritizes profit over resilience.
</respond>
<synthesis>
Mixed models combine public accountability with private efficiency.
</synthesis>
<final>
Critical infrastructure should prioritize public control with operational flexibility.
</final>"""
    },
    # --- Example 48: Global Governance ---
    {
        'Question': 'Is global governance necessary to solve global problems?',
        'Reasoning': """<reasoning>
Transnational issues require coordinated global institutions.
</reasoning>
<critique>
Global governance lacks democratic legitimacy and enforcement power.
</critique>
<respond>
National solutions alone are insufficient for global externalities.
</respond>
<synthesis>
Global cooperation must respect national sovereignty while enabling coordination.
</synthesis>
<final>
Global problems require cooperation, not centralized global authority.
</final>"""
    },
    # --- Example 49: Economic Inequality ---
    {
        'Question': 'Is economic inequality inherently harmful?',
        'Reasoning': """<reasoning>
Inequality rewards productivity and incentivizes innovation.
</reasoning>
<critique>
Excessive inequality undermines social cohesion and political stability.
</critique>
<respond>
Some inequality is unavoidable in dynamic economies.
</respond>
<synthesis>
The problem is not inequality itself, but its scale and persistence.
</synthesis>
<final>
Economic inequality becomes harmful when it concentrates power and opportunity.
</final>"""
    },
    # --- Example 50: Human Purpose in an Automated World ---
    {
        'Question': 'What gives human life purpose in an automated economy?',
        'Reasoning': """<reasoning>
Work provides structure, identity, and meaning.
</reasoning>
<critique>
Automation decouples survival from labor, exposing work as a social construct.
</critique>
<respond>
Humans still seek contribution and recognition.
</respond>
<synthesis>
Purpose shifts from necessity-driven labor to chosen contribution.
</synthesis>
<final>
In an automated world, human purpose comes from voluntary creation, care, and meaning-making.
</final>"""
    }
]

filename = 'hegelian_reasoning_train.csv'

with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
    # Menggunakan Key 'Question' dan 'Reasoning' sesuai data
    fieldnames = ['Question', 'Reasoning'] 
    
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    writer.writerows(data)

print(f"File {filename} berhasil dibuat dengan {len(data)} entri.")
# Out:
# File hegelian_reasoning_train.csv berhasil dibuat dengan 50 entri.

# %%
import csv

# --- TEST SET DATA ---
# Topik-topik ini BARU dan belum pernah dilihat model saat training.
# Gunanya untuk menguji apakah model benar-benar paham "Logika Hegelian",
# atau cuma menghafal jawaban training.

test_data = [
    # --- Test Case 1: Reparations (Keadilan Sejarah) ---
    {
        'Question': 'Should former colonial powers pay reparations to colonized nations?',
        'Reasoning': """<reasoning>
Standard political realism argues no. The individuals responsible are dead, and current taxpayers should not be punished for the sins of ancestors. Furthermore, calculating the monetary value of historical extraction is practically impossible and would bankrupt Western economies.
</reasoning>
<critique>
This ignores "Intergenerational Wealth Accumulation." The poverty of the Global South and the wealth of the North are directly causally linked to that extraction. Time does not erase economic causality. Refusing reparations effectively legitimizes theft as long as you hold the stolen goods long enough.
</critique>
<respond>
However, direct cash transfers might be siphoned by corrupt local elites, failing to help the actual victims' descendants.
</respond>
<synthesis>
The solution is not individual checks (impossible), but *Structural Reparations*. This means debt cancellation, unconditional technology transfer, and funding infrastructure projects. We shift from "guilt money" to "correcting the global balance sheet."
</synthesis>
<final>
Reparations are morally necessary but must take the form of structural investment and debt cancellation rather than unfeasible direct cash payments.
</final>"""
    },

    # --- Test Case 2: AI Art (Estetika & Kemanusiaan) ---
    {
        'Question': 'Is AI-generated art "real" art?',
        'Reasoning': """<reasoning>
Traditionalists say no. Art requires human intent, emotion, and "soul"—the conscious communication of subjective experience. AI merely probabilistically recombines existing pixels without understanding them. It is "content," not art.
</reasoning>
<critique>
This definition is historically fluid. Photography was once called "soulless mechanical reproduction," yet it became art. If the viewer feels emotion, does the origin matter? Moreover, the "prompter" provides the intent; the AI is just a complex brush.
</critique>
<respond>
Yet, the labor dynamic is different. AI scrapes human labor without consent, making it a derivative product of mass plagiarism rather than a new tool.
</respond>
<synthesis>
AI output is *Visual Synthesis*, not Art in the anthropocentric sense. It separates "Aesthetics" (looking good) from "Communication" (meaning something). It forces us to redefine art as *process*, not just *product*.
</synthesis>
<final>
AI generates aesthetic products but lacks the communicative intent of human art. It is a powerful visual tool, but classifying it as "art" requires expanding the definition to include non-human agency.
</final>"""
    },

    # --- Test Case 3: Mandatory Voting (Demokrasi) ---
    {
        'Question': 'Should voting be mandatory in democracies?',
        'Reasoning': """<reasoning>
Yes. Democracy relies on legitimacy derived from the people. Low turnout weakens mandates and allows extremists to dominate. Mandatory voting ensures the government truly represents the median citizen, not just the angry fringe.
</reasoning>
<critique>
Compelled speech violates civil liberties. The right to vote includes the right *not* to vote (silence is a form of protest). Furthermore, forcing uninformed or apathetic people to the polls introduces "random noise" into the election results, potentially lowering the quality of governance.
</critique>
<respond>
Apathy is often structural (voter suppression), not voluntary. The state has an interest in removing barriers.
</respond>
<synthesis>
The synthesis is *Compulsory Attendance* (showing up), not Compulsory Voting. Citizens must present themselves to the civic ritual but can submit a blank ballot. This preserves liberty (the right to choose "none") while enforcing civic duty.
</synthesis>
<final>
Mandatory voting is justified only if it allows for a "None of the Above" option, balancing the state's need for legitimacy with the individual's right to abstain.
</final>"""
    },

    # --- Test Case 4: Genetic Engineering (Etika Biologi) ---
    {
        'Question': 'Should we allow genetic engineering of humans (Designer Babies)?',
        'Reasoning': """<reasoning>
Ethically, no. It risks creating a biological caste system where the rich are genetically superior (smarter, stronger) than the poor. It turns children into designed products rather than gifts, violating human dignity.
</reasoning>
<critique>
We already practice crude eugenics via mate selection. If we have the technology to eliminate suffering (e.g., Huntington's disease, cancer susceptibility), refusing to use it is cruel. Why is "chance" morally superior to "design" if the outcome is health?
</critique>
<respond>
The line between "Therapy" (fixing disease) and "Enhancement" (super-intelligence) is blurry and slippery.
</respond>
<synthesis>
The conflict is solved by regulating *Access*, not the Tech. Genetic editing must be treated like vaccines: if it is safe and effective, it must be universal/free public healthcare, not a luxury good. If everyone is enhanced, inequality does not widen.
</synthesis>
<final>
Genetic engineering is inevitable and ethically permissible for therapy, but requires strict egalitarian distribution to prevent the emergence of a biological class divide.
</final>"""
    },

    # --- Test Case 5: 4-Day Work Week (Ekonomi Kerja) ---
    {
        'Question': 'Is a 4-day work week economically viable?',
        'Reasoning': """<reasoning>
Business logic suggests no. Reducing hours by 20% while paying the same wage increases labor costs per hour. For service and manufacturing industries where output is tied to time, this leads to lower production and inflation.
</reasoning>
<critique>
This assumes humans are machines with linear output. In knowledge work, Parkinson's Law applies: "Work expands to fill the time available." Empirical trials show that rested workers are more intense and focused, maintaining or even increasing total output in fewer hours (efficiency gain).
</critique>
<respond>
However, this efficiency gain doesn't apply to a nurse or security guard who needs to be physically present.
</respond>
<synthesis>
The viability depends on the *Nature of Value*. For output-based work (coding, design), it is viable and superior. For time-based work (care, security), it requires societal subsidization or hiring more staff. We are transitioning from an economy of "Sold Time" to "Delivered Value."
</synthesis>
<final>
A 4-day work week is viable and efficient for the knowledge economy, but requires structural adjustments and cost-sharing for service-based sectors.
</final>"""
    }
]

filename = 'hegelian_reasoning_test.csv'

with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
    # Format kolom sama persis dengan train set
    fieldnames = ['Question', 'Reasoning'] 
    
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    writer.writerows(test_data)

print(f"✅ File TEST SET '{filename}' berhasil dibuat dengan {len(test_data)} soal baru.")
print("Gunakan file ini untuk MENGUJI model setelah training selesai.")
# Out:
# ✅ File TEST SET 'hegelian_reasoning_test.csv' berhasil dibuat dengan 5 soal baru.
# Gunakan file ini untuk MENGUJI model setelah training selesai.
